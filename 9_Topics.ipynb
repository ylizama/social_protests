# %% [markdown]
# ## Topics

# %%
from __future__ import print_function
from time import time

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF
from nltk.corpus import stopwords
import pandas as pd
# %reload_ext cypher
import re

# %%
stop_words_ = set(stopwords.words('english'))  
new_set = set(['000', 'de', 'rt', 'http', 'https', 'amp', '1', '25', 'pm', '2', 'rtudf0a', 'udf0a', 'lifeudc68udfff', 'udfa4udc69udffb', 'udfa8', 'udf08udf37udf3audd16', 'lmaooooooooooooooooooooooooooooooooooooooooooooude02ude02', 'udf31small', '' ])
stop_words_ = stop_words_.union(new_set)

# %% [markdown]
# ## Topics by NMF

# %%
n_top_words = 10
n_features = 10000
n_components = 20
full_topics= {}

def train_NMF(data_samples):
    tfidf_vectorizer = TfidfVectorizer(max_df=1.0, min_df=1,
                                   max_features=n_features,
                                   stop_words=stop_words_)
    tfidf = tfidf_vectorizer.fit_transform(data_samples)

    nmf = NMF(n_components=n_components, random_state=1,
          alpha=.1, l1_ratio=.5).fit(tfidf)
    
    feature_names = tfidf_vectorizer.get_feature_names()
   
    print_top_words(nmf.components_, feature_names, n_top_words)
    
    return nmf, tfidf_vectorizer
      
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model):
        full_topics[topic_idx] = " ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1:-1]])
        print("Topic #%d: " % topic_idx + full_topics[topic_idx] )
        print()
        
def clean_tweets(tweets):
    patternUrl = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    patternUsers =  re.compile('@(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    patternTags = re.compile('#(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    allTweets = pd.Series(tweets).str.cat(sep='\n|\n||\n')
    allTweets = patternUrl.sub('', allTweets) #removing urls 
    allTweets = patternUsers.sub('', allTweets) #removing users
    allTweets = patternTags.sub('', allTweets) #removing tags
    return allTweets.split('\n|\n||\n')

# %%
ecos = [ 'BLM', 'MT', 'CCH', 'GC']
for eco in ecos:
    tweetsQ = %cypher match  (n:tweet)<-[r :TWEETS]-(n2:user) where n.eco = '{eco}' and n.lang='en' return substring(n.text, 0, 10000000) as text
    training_data = clean_tweets(tweetsQ.get_dataframe().text.unique())
    print(eco, len(training_data), 'tweets -------------------------------------------------------------------')
#
# 37086 rows affected.
# CCH 18771 tweets -------------------------------------------------------------------
# Topic #0: extended deadline eastern participate special 11 month end week 2018
#
# Topic #1: multiplied billions worldudf33 transform acts gain follow followers followback people
#
# Topic #2: latest thanks daily news abbottabad climate times green sustainability watchdog
#
# Topic #3: climate change impacts threat action report risks health affect link
#
# Topic #4: create save valuable kindness simplest comeudf32rt udc4dfollo better powerful minutes
#
# Topic #5: great need good make planet like future news people see
#
# Topic #6: greenhouse gas trump nasa research cuts house white cancels quietly
#
# Topic #7: new california homes solar require state panels first becomes mandate
#
# Topic #8: via stories effects daily countries affect rich developing ones top
#
# Topic #9: global warming melting antarctic ice unity4 worldudf33rt issues abraham john
#
# Topic #10: post 05 processing 10 2018 direct may blog million season
#
# Topic #11: chemtrails obvious clouds airplane planes seen smell able actually father
#
# Topic #12: world around lizards resilient threaten one rest even first better
#
# Topic #13: fossil rica costa ban fuels first become decarbonised society president
#
# Topic #14: arctic ice learn sea melting heat level threat rise winter
#
# Topic #15: support contribute minutes cause worldudc90 eachotherudf32 udf31follow small gain valuable
#
# Topic #16: us join help save tell state first becomes mandate discuss
#
# Topic #17: energy renewable clean 100 jobs learn sustainable solar source wind
#
# Topic #18: time act first running cheaper spending nature fight greenpeace dealing
#
# Topic #19: carbon emissions dioxide tourism footprint reduce co2 monitoring atmosphere trading
#
# 491128 rows affected.
# GC 112213 tweets -------------------------------------------------------------------
# Topic #0: shootings one like school right us would mass going want
#
# Topic #1: edition limited get stores sold shirt store rid let together
#
# Topic #2: school shooting fe santa high another texas dead 10 students
#
# Topic #3: prayers thoughts action working useless nothing sending victims families something
#
# Topic #4: trump donald president gop video administration obama lies support supporters
#
# Topic #5: gun control laws violence reform sense common owners sensible work
#
# Topic #6: need change action better schools laws die control protect help
#
# Topic #7: guns problem ban kill away access take doors guys good
#
# Topic #8: enough going said already yet angry sit say twitter retweet
#
# Topic #9: children death protect lives dead future schools dying safe parents
#
# Topic #10: white privilege racism racist bitch said minorities saying say insulting
#
# Topic #11: people kill killed young 10 murdered innocent memory died military
#
# Topic #12: time talk another every good yet past action last soon
#
# Topic #13: stop needs must violence madness please taking going killing shootings
#
# Topic #14: america another wake needs day great problem yet vs world
#
# Topic #15: many something die lives done must times innocent change take
#
# Topic #16: texas cruz ted pagourtzis dimitrios peterson pigs filthy ing filth
#
# Topic #17: kids parents school dead schools safe keep die dying killed
#
# Topic #18: nra vote money blood hands gop politicians take republicans november
#
# Topic #19: fuck shut fucking bitch go shit give girl nra actual
