# %%
# %reload_ext cypher
import matplotlib
import pandas as pd
import matplotlib.pyplot
import datetime
import string
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk import ngrams
import operator
from itertools import islice
from tabulate import tabulate
pd.set_option('display.max_colwidth', -1)
import re

# %%
def clean_tweets(tweets):
    patternUrl = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    patternUsers =  re.compile('@(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    patternTags = re.compile('#(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    allTweets = pd.Series(tweets).str.cat(sep='\n|\n||\n')
    allTweets = patternUrl.sub('', allTweets) #removing urls 
    allTweets = patternUsers.sub('', allTweets) #removing users
    allTweets = patternTags.sub('', allTweets) #removing tags
    return allTweets

# %%
stop_words_ = set(stopwords.words('english'))  
new_set = set(['000', 'de', 'rt', 'http', 'https', 'amp', '1', '25', 'pm', '2', 'rtudf0a', 'udf0a', 'lifeudc68udfff', 'udfa4udc69udffb', 'udfa8', 'udf08udf37udf3audd16', 'lmaooooooooooooooooooooooooooooooooooooooooooooude02ude02', 'udf31small', '' ])
stop_words_ = stop_words_.union(new_set)

# %%
def getNGram(text, n, stop_words, m):
    punct_signs = list(string.punctuation)
    punct_signs.append('…')
    punct_signs.append('¿')
    for p in punct_signs:
        text = text.replace(p, ' ')
    clean_text = text.lower().split()
    clean_text = [w for w in clean_text if w not in stop_words_]
    total = len(clean_text)
    h_dict = {}   
    ngramas = ngrams(clean_text, n)
    for grams in ngramas:
        words = ' '.join(grams)        
        words = words.strip() 
        if words in h_dict:
            h_dict[words] = h_dict[words] + 1
        else: 
            h_dict[words] = 1 
    sorted_dict = sorted(h_dict.items(), key=operator.itemgetter(1), reverse=True)
    if m >=1:
        results = list(islice(sorted_dict,  m))
        results = [(v[0], v[1], v[1] * 100 / total) for v in results]
        return results
    else:
        return list(islice(sorted_dict, None))

# %%
ecos = [ 'BLM', 'MT', 'CCH', 'GC']
tweets_text = []

# %%
for eco in ecos:
    tweetsQ = %cypher match  (n:tweet)<-[r :TWEETS]-(n2:user) where n.eco = '{eco}' and n.lang = 'en' return n.tid as tid, substring(n.text, 0, 10000000) as text, n.created_at as date
    text = clean_tweets(tweetsQ.get_dataframe().text)
    tweets_text.append(text)
# Out:
# 52663 rows affected.
# 363557 rows affected.
# 37086 rows affected.
# 491128 rows affected.

# %% [markdown]
# ## Top 50 unigrams in tweets per Movement

# %%
for idx, eco in enumerate(ecos):
    print()
    print(eco)
    print('-----------------------------------------------------------------------')
    final = getNGram(tweets_text[idx], 1, stop_words_, 50)
    df = pd.DataFrame([x for x in final], columns = ['Ngram', 'Number', '% of the total'])
    display(df)
    print('-----------------------------------------------------------------------')
# Out:
# BLM
# -----------------------------------------------------------------------
#         Ngram  Number  % of the total
# 0   black      14636   2.922962
# 1   police     6352    1.268561
# 2   white      6247    1.247591
# 3   people     6068    1.211843
# 4   cops       4882    0.974986
# 5   follow     3905    0.779869
# 6   party      3333    0.665635
# 7   killed     2899    0.578961
# 8   rt♻️       2818    0.562784
# 9   like❤      2818    0.562784
# 10  outrage    2730    0.545209
# 11  man        2701    0.539418
# 12  days       2616    0.522442
# 13  icymi      2487    0.496680
# 14  four       2454    0.490089
# 15  larry      2415    0.482301
# 16  elder      2411    0.481502
# 17  seven      2407    0.480703
# 18  student    1996    0.398622
# 19  like       1924    0.384243
# 20  it’s       1872    0.373858
# 21  time       1851    0.369664
# 22  lives      1844    0.368266
# 23  make       1826    0.364671
# 24  racist     1822    0.363872
# ...

# %% [markdown]
# ## Top 50 bigrams in the tweets per Movement

# %%
for idx, actor in enumerate(ecos):
    print()
    print(actor)
    print('-----------------------------------------------------------------------')
    final = getNGram(tweets_text[idx], 2, stop_words_, 50)
    df = pd.DataFrame([x for x in final], columns = ['Ngram', 'Number', '% of the total'])
    display(df)
# Out:
# BLM
# -----------------------------------------------------------------------
#                   Ngram  Number  % of the total
# 0   like❤ rt♻️           2818    0.562784
# 1   party like❤          2818    0.562784
# 2   rt♻️ follow          2818    0.562784
# 3   black cops           2409    0.481102
# 4   larry elder          2408    0.480903
# 5   icymi larry          2406    0.480503
# 6   cops killed          2403    0.479904
# 7   four black           2389    0.477108
# 8   seven days           2387    0.476709
# 9   killed seven         2387    0.476709
# 10  elder four           2386    0.476509
# 11  days outrage         2386    0.476509
# 12  white people         2331    0.465525
# 13  black man            1826    0.364671
# 14  call police          1152    0.230066
# 15  black people         1140    0.227670
# 16  black student        1082    0.216087
# 17  nap dorm             1051    0.209896
# 18  it’s time            1043    0.208298
# ...

# %% [markdown]
# # Top 50 bigrams in the tweets per Movement

# %%
for idx, actor in enumerate(ecos):
    print()
    print(actor)
    print('--------------------')
    final = getNGram(tweets_text[idx], 3, stop_words_, 50)
    df = pd.DataFrame([x for x in final], columns = ['Ngram', 'Number', '% of the total'])
    display(df)
# Out:
# BLM
# --------------------
#                                                Ngram  Number  % of the total
# 0   party like❤ rt♻️                                  2818    0.562784
# 1   like❤ rt♻️ follow                                 2818    0.562784
# 2   icymi larry elder                                 2406    0.480503
# 3   black cops killed                                 2398    0.478906
# 4   four black cops                                   2388    0.476908
# 5   killed seven days                                 2387    0.476709
# 6   larry elder four                                  2386    0.476509
# 7   seven days outrage                                2386    0.476509
# 8   cops killed seven                                 2386    0.476509
# 9   elder four black                                  2386    0.476509
# 10  student taking nap                                1024    0.204503
# 11  black student taking                              1023    0.204304
# ...

# %% [markdown]
# ## Number of Tweets per Movement

# %%
# %cypher match (n:tweet) return n.eco as Movement, count(n)  as  Tweets
# Out:
# 4 rows affected.
# [['CCH', 40616], ['GC', 527641], ['MT', 596798], ['BLM', 60960]]

# %% [markdown]
# ## Top 20 Hashtags per Movement - includes non-english hashtags

# %%
for eco in ecos:
    print(eco, '----------------------------------------------')
    df = %cypher match (n:hashtag)-[r]-() where n.eco = '{eco}' return n.hashtag as Hashtag, count(r) as degree order by degree desc limit 20
    display (df.get_dataframe())
# Out:
# BLM ----------------------------------------------
# 20 rows affected.
#              Hashtag  degree
# 0   metoo             245944
# 1   guncontrol        74867
# 2   guncontrolnow     64838
# 3   blacklivesmatter  17833
# 4   climatechange     14646
# 5   timesup           10886
# 6   nra               8450
# 7   fbr               6952
# 8   marchforourlives  6778
# 9   theresistance     6589
# 10  trump             6061
# 11  neveragain        5925
# 12  resist            5561
# 13  gunreformnow      5486
# 14  texas             5343
# 15  maga              5313
# 16  enoughisenough    4918
# 17  resistance        4509
# 18  impeachtrump      4089
# 19  bluewave2018      4007
# MT ----------------------------------------------
# 20 rows affected.
#                        Hashtag  degree
# 0   santafe                     10013
# 1   harveyweinstein             4383
# 2   morganfreeman               3134
# 3   weinstein                   3117
# 4   미투                          3093
# ...
